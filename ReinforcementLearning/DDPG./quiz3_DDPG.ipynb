# %%
import sys
print("Python executable:", sys.executable)
import gymnasium as gym
import stable_baselines3
import torch
import pygame

print("All imports successful!")
# Out:
# Python executable: C:\Users\omar\anaconda3\envs\lunarlander\python.exe
# All imports successful!

# %%
# 📌 Step 1: Imports
import gymnasium as gym  # Use gymnasium instead of gym
import numpy as np
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import torch
import os

env = gym.make("LunarLanderContinuous-v3", render_mode="human")  # Use v3
env = Monitor(env)  # For logging
env = DummyVecEnv([lambda: env])  # Vectorized wrapper for compatibility


n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))


log_dir = "./ddpg_lunar_tensorboard/"
os.makedirs(log_dir, exist_ok=True)

new_logger = configure(log_dir, ["stdout", "tensorboard"])


model = DDPG(
    "MlpPolicy",
    env,
    learning_rate=1e-3,
    batch_size=64,
    gamma=0.99,
    action_noise=action_noise,
    learning_starts=50000,
    verbose=1,
    tensorboard_log=log_dir,
)


model.set_logger(new_logger)


model.learn(total_timesteps=250000)


model.save("ddpg_lunarlander_model")


test_env = gym.make("LunarLanderContinuous-v3", render_mode="human")
obs, _ = test_env.reset()
done = False
while not done:
    test_env.render()
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = test_env.step(action)
    done = terminated or truncated
test_env.close()
# Out:
# Logging to ./ddpg_lunar_tensorboard/
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | -206     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 41       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 502      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 128      |
# |    ep_rew_mean     | -254     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 44       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1025     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | -257     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 45       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 1407     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | -253     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 46       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 1915     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 115      |
# |    ep_rew_mean     | -228     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 46       |
# |    time_elapsed    | 49       |
# |    total_timesteps | 2293     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -230     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 46       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 2703     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 46       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 3098     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -230     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 46       |
# |    time_elapsed    | 74       |
# |    total_timesteps | 3502     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 46       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 3903     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -227     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 46       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 4270     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -232     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 46       |
# |    time_elapsed    | 100      |
# |    total_timesteps | 4709     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -233     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 46       |
# |    time_elapsed    | 110      |
# |    total_timesteps | 5169     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 47       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 5634     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -231     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 47       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 6311     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 47       |
# |    time_elapsed    | 142      |
# |    total_timesteps | 6703     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 47       |
# |    time_elapsed    | 150      |
# |    total_timesteps | 7114     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -240     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 47       |
# |    time_elapsed    | 160      |
# |    total_timesteps | 7571     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -240     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 47       |
# |    time_elapsed    | 172      |
# |    total_timesteps | 8146     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -240     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 47       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 8517     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 47       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 8932     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -234     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 47       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 9288     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 47       |
# |    time_elapsed    | 205      |
# |    total_timesteps | 9689     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -238     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 47       |
# |    time_elapsed    | 215      |
# |    total_timesteps | 10172    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -242     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 47       |
# |    time_elapsed    | 225      |
# |    total_timesteps | 10638    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -241     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 47       |
# |    time_elapsed    | 236      |
# |    total_timesteps | 11156    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -244     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 47       |
# |    time_elapsed    | 244      |
# |    total_timesteps | 11565    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -239     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 47       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 11957    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -236     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 47       |
# |    time_elapsed    | 261      |
# |    total_timesteps | 12353    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 47       |
# |    time_elapsed    | 270      |
# |    total_timesteps | 12772    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -236     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 47       |
# |    time_elapsed    | 278      |
# |    total_timesteps | 13167    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 47       |
# |    time_elapsed    | 287      |
# |    total_timesteps | 13607    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -234     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 47       |
# |    time_elapsed    | 296      |
# |    total_timesteps | 14043    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 47       |
# |    time_elapsed    | 307      |
# |    total_timesteps | 14569    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -236     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 47       |
# |    time_elapsed    | 318      |
# |    total_timesteps | 15063    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -230     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 47       |
# |    time_elapsed    | 328      |
# |    total_timesteps | 15532    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 47       |
# |    time_elapsed    | 336      |
# |    total_timesteps | 15933    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -224     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 47       |
# |    time_elapsed    | 345      |
# |    total_timesteps | 16341    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 47       |
# |    time_elapsed    | 355      |
# |    total_timesteps | 16822    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -220     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 47       |
# |    time_elapsed    | 363      |
# |    total_timesteps | 17229    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 47       |
# |    time_elapsed    | 373      |
# |    total_timesteps | 17680    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 47       |
# |    time_elapsed    | 381      |
# |    total_timesteps | 18080    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 47       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 18539    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -205     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 47       |
# |    time_elapsed    | 399      |
# |    total_timesteps | 18919    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 47       |
# |    time_elapsed    | 407      |
# |    total_timesteps | 19297    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -212     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 47       |
# |    time_elapsed    | 415      |
# |    total_timesteps | 19712    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -212     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 47       |
# |    time_elapsed    | 424      |
# |    total_timesteps | 20147    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -206     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 47       |
# |    time_elapsed    | 432      |
# |    total_timesteps | 20500    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -203     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 47       |
# |    time_elapsed    | 441      |
# |    total_timesteps | 20946    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -196     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 47       |
# |    time_elapsed    | 449      |
# |    total_timesteps | 21299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -197     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 47       |
# |    time_elapsed    | 457      |
# |    total_timesteps | 21707    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -195     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 47       |
# |    time_elapsed    | 466      |
# |    total_timesteps | 22119    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 47       |
# |    time_elapsed    | 475      |
# |    total_timesteps | 22546    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 47       |
# |    time_elapsed    | 483      |
# |    total_timesteps | 22937    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 47       |
# |    time_elapsed    | 491      |
# |    total_timesteps | 23328    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -195     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 47       |
# |    time_elapsed    | 500      |
# |    total_timesteps | 23744    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -198     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 47       |
# |    time_elapsed    | 510      |
# |    total_timesteps | 24198    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -196     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 47       |
# |    time_elapsed    | 518      |
# |    total_timesteps | 24606    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -202     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 47       |
# |    time_elapsed    | 527      |
# |    total_timesteps | 25013    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -204     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 47       |
# |    time_elapsed    | 534      |
# |    total_timesteps | 25370    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 47       |
# |    time_elapsed    | 544      |
# |    total_timesteps | 25849    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -213     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 47       |
# |    time_elapsed    | 552      |
# |    total_timesteps | 26218    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 47       |
# |    time_elapsed    | 562      |
# |    total_timesteps | 26696    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 47       |
# |    time_elapsed    | 572      |
# |    total_timesteps | 27181    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 47       |
# |    time_elapsed    | 580      |
# |    total_timesteps | 27559    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -222     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 47       |
# |    time_elapsed    | 587      |
# |    total_timesteps | 27891    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 47       |
# |    time_elapsed    | 596      |
# |    total_timesteps | 28337    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -220     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 47       |
# |    time_elapsed    | 608      |
# |    total_timesteps | 28898    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 47       |
# |    time_elapsed    | 616      |
# |    total_timesteps | 29259    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 47       |
# |    time_elapsed    | 625      |
# |    total_timesteps | 29685    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -209     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 47       |
# |    time_elapsed    | 634      |
# |    total_timesteps | 30106    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -209     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 47       |
# |    time_elapsed    | 642      |
# |    total_timesteps | 30493    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 47       |
# |    time_elapsed    | 652      |
# |    total_timesteps | 30962    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 47       |
# |    time_elapsed    | 660      |
# |    total_timesteps | 31367    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -219     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 47       |
# |    time_elapsed    | 668      |
# |    total_timesteps | 31743    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 47       |
# |    time_elapsed    | 678      |
# |    total_timesteps | 32226    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 47       |
# |    time_elapsed    | 687      |
# |    total_timesteps | 32643    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 47       |
# |    time_elapsed    | 696      |
# |    total_timesteps | 33092    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -222     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 47       |
# |    time_elapsed    | 705      |
# |    total_timesteps | 33499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 47       |
# |    time_elapsed    | 714      |
# |    total_timesteps | 33918    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -221     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 47       |
# |    time_elapsed    | 723      |
# |    total_timesteps | 34374    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 47       |
# |    time_elapsed    | 731      |
# |    total_timesteps | 34759    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 47       |
# |    time_elapsed    | 743      |
# |    total_timesteps | 35305    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 47       |
# |    time_elapsed    | 751      |
# |    total_timesteps | 35700    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 47       |
# |    time_elapsed    | 759      |
# |    total_timesteps | 36061    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -212     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 47       |
# |    time_elapsed    | 767      |
# |    total_timesteps | 36484    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 47       |
# |    time_elapsed    | 775      |
# |    total_timesteps | 36863    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 47       |
# |    time_elapsed    | 784      |
# |    total_timesteps | 37255    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 47       |
# |    time_elapsed    | 794      |
# |    total_timesteps | 37732    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 47       |
# |    time_elapsed    | 803      |
# |    total_timesteps | 38170    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 47       |
# |    time_elapsed    | 813      |
# |    total_timesteps | 38639    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 47       |
# |    time_elapsed    | 824      |
# |    total_timesteps | 39188    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -219     |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 47       |
# |    time_elapsed    | 834      |
# |    total_timesteps | 39669    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 47       |
# |    time_elapsed    | 843      |
# |    total_timesteps | 40106    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 47       |
# |    time_elapsed    | 853      |
# |    total_timesteps | 40543    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 47       |
# |    time_elapsed    | 862      |
# |    total_timesteps | 40992    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 47       |
# |    time_elapsed    | 871      |
# |    total_timesteps | 41415    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -224     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 47       |
# |    time_elapsed    | 879      |
# |    total_timesteps | 41803    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 47       |
# |    time_elapsed    | 889      |
# |    total_timesteps | 42267    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 47       |
# |    time_elapsed    | 897      |
# |    total_timesteps | 42672    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 47       |
# |    time_elapsed    | 906      |
# |    total_timesteps | 43091    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -230     |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 47       |
# |    time_elapsed    | 914      |
# |    total_timesteps | 43496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -233     |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 47       |
# |    time_elapsed    | 923      |
# |    total_timesteps | 43924    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -232     |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 47       |
# |    time_elapsed    | 934      |
# |    total_timesteps | 44406    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -228     |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 47       |
# |    time_elapsed    | 942      |
# |    total_timesteps | 44830    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 47       |
# |    time_elapsed    | 950      |
# |    total_timesteps | 45205    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -228     |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 47       |
# |    time_elapsed    | 959      |
# |    total_timesteps | 45621    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 47       |
# |    time_elapsed    | 967      |
# |    total_timesteps | 46015    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 47       |
# |    time_elapsed    | 978      |
# |    total_timesteps | 46524    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 47       |
# |    time_elapsed    | 986      |
# |    total_timesteps | 46914    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -224     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 47       |
# |    time_elapsed    | 996      |
# |    total_timesteps | 47402    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 47       |
# |    time_elapsed    | 1004     |
# |    total_timesteps | 47746    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -213     |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 47       |
# |    time_elapsed    | 1011     |
# |    total_timesteps | 48104    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 47       |
# |    time_elapsed    | 1019     |
# |    total_timesteps | 48488    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 47       |
# |    time_elapsed    | 1027     |
# |    total_timesteps | 48833    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 47       |
# |    time_elapsed    | 1035     |
# |    total_timesteps | 49213    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 47       |
# |    time_elapsed    | 1042     |
# |    total_timesteps | 49586    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -213     |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 47       |
# |    time_elapsed    | 1050     |
# |    total_timesteps | 49926    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 47       |
# |    time_elapsed    | 1091     |
# |    total_timesteps | 51924    |
# | train/             |          |
# |    actor_loss      | 2.73     |
# |    critic_loss     | 9.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1923     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 147      |
# |    ep_rew_mean     | -204     |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 47       |
# |    time_elapsed    | 1158     |
# |    total_timesteps | 55207    |
# | train/             |          |
# |    actor_loss      | -5.38    |
# |    critic_loss     | 147      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5206     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 156      |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 47       |
# |    time_elapsed    | 1187     |
# |    total_timesteps | 56602    |
# | train/             |          |
# |    actor_loss      | -7.89    |
# |    critic_loss     | 10.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6601     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 47       |
# |    time_elapsed    | 1210     |
# |    total_timesteps | 57707    |
# | train/             |          |
# |    actor_loss      | -25.1    |
# |    critic_loss     | 181      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7706     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 168      |
# |    ep_rew_mean     | -181     |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 47       |
# |    time_elapsed    | 1229     |
# |    total_timesteps | 58639    |
# | train/             |          |
# |    actor_loss      | -26.7    |
# |    critic_loss     | 37.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8638     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 182      |
# |    ep_rew_mean     | -166     |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 47       |
# |    time_elapsed    | 1267     |
# |    total_timesteps | 60466    |
# | train/             |          |
# |    actor_loss      | -28.7    |
# |    critic_loss     | 29.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10465    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | -156     |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 47       |
# |    time_elapsed    | 1293     |
# |    total_timesteps | 61753    |
# | train/             |          |
# |    actor_loss      | -42      |
# |    critic_loss     | 5.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11752    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | -146     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 47       |
# |    time_elapsed    | 1318     |
# |    total_timesteps | 62922    |
# | train/             |          |
# |    actor_loss      | -52.4    |
# |    critic_loss     | 20       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12921    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | -137     |
# | time/              |          |
# |    episodes        | 504      |
# |    fps             | 47       |
# |    time_elapsed    | 1334     |
# |    total_timesteps | 63722    |
# | train/             |          |
# |    actor_loss      | -43.6    |
# |    critic_loss     | 18.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13721    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | -125     |
# | time/              |          |
# |    episodes        | 508      |
# |    fps             | 47       |
# |    time_elapsed    | 1371     |
# |    total_timesteps | 65510    |
# | train/             |          |
# |    actor_loss      | -50.9    |
# |    critic_loss     | 8.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15509    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 512      |
# |    fps             | 47       |
# |    time_elapsed    | 1398     |
# |    total_timesteps | 66799    |
# | train/             |          |
# |    actor_loss      | -45.8    |
# |    critic_loss     | 21.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16798    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 516      |
# |    fps             | 47       |
# |    time_elapsed    | 1440     |
# |    total_timesteps | 68837    |
# | train/             |          |
# |    actor_loss      | -68.7    |
# |    critic_loss     | 33.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18836    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 259      |
# |    ep_rew_mean     | -109     |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 47       |
# |    time_elapsed    | 1487     |
# |    total_timesteps | 71137    |
# | train/             |          |
# |    actor_loss      | -49.1    |
# |    critic_loss     | 7.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21136    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 274      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 524      |
# |    fps             | 47       |
# |    time_elapsed    | 1525     |
# |    total_timesteps | 73002    |
# | train/             |          |
# |    actor_loss      | -55.9    |
# |    critic_loss     | 17.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23001    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 528      |
# |    fps             | 47       |
# |    time_elapsed    | 1598     |
# |    total_timesteps | 76514    |
# | train/             |          |
# |    actor_loss      | -66.1    |
# |    critic_loss     | 15.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26513    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 532      |
# |    fps             | 47       |
# |    time_elapsed    | 1669     |
# |    total_timesteps | 80008    |
# | train/             |          |
# |    actor_loss      | -85.6    |
# |    critic_loss     | 30.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30007    |
# ---------------------------------
# ...
# |    actor_loss      | -105     |
# |    critic_loss     | 6.54     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 128439   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 777      |
# |    ep_rew_mean     | -61.4    |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 48       |
# |    time_elapsed    | 3776     |
# |    total_timesteps | 182440   |
# | train/             |          |
# |    actor_loss      | -87.5    |
# |    critic_loss     | 8.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 132439   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 782      |
# |    ep_rew_mean     | -60.1    |
# | time/              |          |
# |    episodes        | 664      |
# |    fps             | 48       |
# |    time_elapsed    | 3858     |
# |    total_timesteps | 186440   |
# | train/             |          |
# |    actor_loss      | -86      |
# |    critic_loss     | 7.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 136439   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 768      |
# |    ep_rew_mean     | -58.8    |
# | time/              |          |
# |    episodes        | 668      |
# |    fps             | 48       |
# |    time_elapsed    | 3911     |
# |    total_timesteps | 189020   |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 4.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 139019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 768      |
# |    ep_rew_mean     | -57.9    |
# | time/              |          |
# |    episodes        | 672      |
# |    fps             | 48       |
# |    time_elapsed    | 3994     |
# |    total_timesteps | 193020   |
# | train/             |          |
# |    actor_loss      | -91.6    |
# |    critic_loss     | 5.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 143019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 776      |
# |    ep_rew_mean     | -50.4    |
# | time/              |          |
# |    episodes        | 676      |
# |    fps             | 48       |
# |    time_elapsed    | 4076     |
# |    total_timesteps | 196971   |
# | train/             |          |
# |    actor_loss      | -76      |
# |    critic_loss     | 19       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146970   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 783      |
# |    ep_rew_mean     | -48.4    |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 48       |
# |    time_elapsed    | 4147     |
# |    total_timesteps | 200431   |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 2.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 150430   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 778      |
# |    ep_rew_mean     | -48.1    |
# | time/              |          |
# |    episodes        | 684      |
# |    fps             | 48       |
# |    time_elapsed    | 4218     |
# |    total_timesteps | 203887   |
# | train/             |          |
# |    actor_loss      | -85.5    |
# |    critic_loss     | 210      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 153886   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 777      |
# |    ep_rew_mean     | -44.4    |
# | time/              |          |
# |    episodes        | 688      |
# |    fps             | 48       |
# |    time_elapsed    | 4288     |
# |    total_timesteps | 207291   |
# | train/             |          |
# |    actor_loss      | -66.8    |
# |    critic_loss     | 8.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 157290   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 779      |
# |    ep_rew_mean     | -41.7    |
# | time/              |          |
# |    episodes        | 692      |
# |    fps             | 48       |
# |    time_elapsed    | 4349     |
# |    total_timesteps | 210224   |
# | train/             |          |
# |    actor_loss      | -78.9    |
# |    critic_loss     | 3.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 160223   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 791      |
# |    ep_rew_mean     | -29.7    |
# | time/              |          |
# |    episodes        | 696      |
# |    fps             | 48       |
# |    time_elapsed    | 4413     |
# |    total_timesteps | 213327   |
# | train/             |          |
# |    actor_loss      | -89.8    |
# |    critic_loss     | 19.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 163326   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 789      |
# |    ep_rew_mean     | -23.6    |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 48       |
# |    time_elapsed    | 4438     |
# |    total_timesteps | 214555   |
# | train/             |          |
# |    actor_loss      | -80.4    |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 164554   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 789      |
# |    ep_rew_mean     | -21.9    |
# | time/              |          |
# |    episodes        | 704      |
# |    fps             | 48       |
# |    time_elapsed    | 4477     |
# |    total_timesteps | 216443   |
# | train/             |          |
# |    actor_loss      | -93.6    |
# |    critic_loss     | 16.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 166442   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 781      |
# |    ep_rew_mean     | -18.4    |
# | time/              |          |
# |    episodes        | 708      |
# |    fps             | 48       |
# |    time_elapsed    | 4498     |
# |    total_timesteps | 217443   |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 2.89     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 167442   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 762      |
# |    ep_rew_mean     | -17.5    |
# | time/              |          |
# |    episodes        | 712      |
# |    fps             | 48       |
# |    time_elapsed    | 4527     |
# |    total_timesteps | 218888   |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 5.69     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 168887   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 749      |
# |    ep_rew_mean     | -5.69    |
# | time/              |          |
# |    episodes        | 716      |
# |    fps             | 48       |
# |    time_elapsed    | 4565     |
# |    total_timesteps | 220727   |
# | train/             |          |
# |    actor_loss      | -82.6    |
# |    critic_loss     | 4.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 170726   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 749      |
# |    ep_rew_mean     | -5.3     |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 48       |
# |    time_elapsed    | 4613     |
# |    total_timesteps | 223029   |
# | train/             |          |
# |    actor_loss      | -82.4    |
# |    critic_loss     | 3.26     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173028   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 734      |
# |    ep_rew_mean     | 0.463    |
# | time/              |          |
# |    episodes        | 724      |
# |    fps             | 48       |
# |    time_elapsed    | 4649     |
# |    total_timesteps | 224796   |
# | train/             |          |
# |    actor_loss      | -64.7    |
# |    critic_loss     | 6.92     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174795   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 726      |
# |    ep_rew_mean     | 7.95     |
# | time/              |          |
# |    episodes        | 728      |
# |    fps             | 48       |
# |    time_elapsed    | 4699     |
# |    total_timesteps | 227184   |
# | train/             |          |
# |    actor_loss      | -71.6    |
# |    critic_loss     | 18.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177183   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 714      |
# |    ep_rew_mean     | 18.5     |
# | time/              |          |
# |    episodes        | 732      |
# |    fps             | 48       |
# |    time_elapsed    | 4745     |
# |    total_timesteps | 229428   |
# | train/             |          |
# |    actor_loss      | -80.4    |
# |    critic_loss     | 3.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179427   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 712      |
# |    ep_rew_mean     | 24.2     |
# | time/              |          |
# |    episodes        | 736      |
# |    fps             | 48       |
# |    time_elapsed    | 4796     |
# |    total_timesteps | 231891   |
# | train/             |          |
# |    actor_loss      | -76.7    |
# |    critic_loss     | 33.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 181890   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 687      |
# |    ep_rew_mean     | 27.1     |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 48       |
# |    time_elapsed    | 4826     |
# |    total_timesteps | 233383   |
# | train/             |          |
# |    actor_loss      | -80.3    |
# |    critic_loss     | 2.8      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 183382   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 688      |
# |    ep_rew_mean     | 28.2     |
# | time/              |          |
# |    episodes        | 744      |
# |    fps             | 48       |
# |    time_elapsed    | 4871     |
# |    total_timesteps | 235556   |
# | train/             |          |
# |    actor_loss      | -75.8    |
# |    critic_loss     | 5.87     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 185555   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 662      |
# |    ep_rew_mean     | 30.7     |
# | time/              |          |
# |    episodes        | 748      |
# |    fps             | 48       |
# |    time_elapsed    | 4894     |
# |    total_timesteps | 236649   |
# | train/             |          |
# |    actor_loss      | -80      |
# |    critic_loss     | 3.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 186648   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 643      |
# |    ep_rew_mean     | 39.6     |
# | time/              |          |
# |    episodes        | 752      |
# |    fps             | 48       |
# |    time_elapsed    | 4936     |
# |    total_timesteps | 238708   |
# | train/             |          |
# |    actor_loss      | -82.3    |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 188707   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 622      |
# |    ep_rew_mean     | 46.9     |
# | time/              |          |
# |    episodes        | 756      |
# |    fps             | 48       |
# |    time_elapsed    | 4975     |
# |    total_timesteps | 240606   |
# | train/             |          |
# |    actor_loss      | -76.4    |
# |    critic_loss     | 63.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 190605   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 597      |
# |    ep_rew_mean     | 54.7     |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 48       |
# |    time_elapsed    | 5007     |
# |    total_timesteps | 242112   |
# | train/             |          |
# |    actor_loss      | -79.5    |
# |    critic_loss     | 3.7      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 192111   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 572      |
# |    ep_rew_mean     | 62.5     |
# | time/              |          |
# |    episodes        | 764      |
# |    fps             | 48       |
# |    time_elapsed    | 5038     |
# |    total_timesteps | 243621   |
# | train/             |          |
# |    actor_loss      | -78      |
# |    critic_loss     | 3.89     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 193620   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 559      |
# |    ep_rew_mean     | 72.1     |
# | time/              |          |
# |    episodes        | 768      |
# |    fps             | 48       |
# |    time_elapsed    | 5064     |
# |    total_timesteps | 244873   |
# | train/             |          |
# |    actor_loss      | -78.7    |
# |    critic_loss     | 7.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 194872   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 534      |
# |    ep_rew_mean     | 80.2     |
# | time/              |          |
# |    episodes        | 772      |
# |    fps             | 48       |
# |    time_elapsed    | 5096     |
# |    total_timesteps | 246460   |
# | train/             |          |
# |    actor_loss      | -76.8    |
# |    critic_loss     | 211      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 196459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 506      |
# |    ep_rew_mean     | 77.3     |
# | time/              |          |
# |    episodes        | 776      |
# |    fps             | 48       |
# |    time_elapsed    | 5119     |
# |    total_timesteps | 247543   |
# | train/             |          |
# |    actor_loss      | -76.8    |
# |    critic_loss     | 4.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197542   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 490      |
# |    ep_rew_mean     | 89.4     |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 48       |
# |    time_elapsed    | 5158     |
# |    total_timesteps | 249414   |
# | train/             |          |
# |    actor_loss      | -73.7    |
# |    critic_loss     | 7.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199413   |
# ---------------------------------
